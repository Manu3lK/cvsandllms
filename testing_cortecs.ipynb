# %%
from langchain_openai import ChatOpenAI

# %%
import os

cortecs_api_key = "6277c98bf1b17ae026b9e42478b23c3e682caf19965c6368"
os.environ["OPENAI_API_KEY"] = cortecs_api_key

llm = ChatOpenAI(openai_api_base="https://tmxn-369361.cortecs.eu/v1",
                 model_name="cortecs/Mistral-Small-24B-Instruct-2501-FP8-Dynamic")

# %%
res = llm.invoke("Tell me a joke")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 res = llm.invoke("Tell me a joke")
#
# File c:\Users\Manuel\Anaconda3\envs\allgemeines_env\Lib\site-packages\langchain_core\language_models\chat_models.py:285, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     274 def invoke(
#     275     self,
#     276     input: LanguageModelInput,
#    (...)
#     280     **kwargs: Any,
#     281 ) -> BaseMessage:
#     282     config = ensure_config(config)
#     283     return cast(
#     284         ChatGeneration,
# --> 285         self.generate_prompt(
#     286             [self._convert_input(input)],
#     287             stop=stop,
#     288             callbacks=config.get("callbacks"),
#     289             tags=config.get("tags"),
#     290             metadata=config.get("metadata"),
# ...

# %%
res.text()
# Out:
# "Sure, here's one for you:\n\nWhat do you call fake spaghetti?\nAn impasta."

# %%
res.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Sure, here's one for you:
#
# What do you call fake spaghetti?
# An impasta.

# %%
res
# Out:
# AIMessage(content="Sure, here's one for you:\n\nWhat do you call fake spaghetti?\nAn impasta.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 181, 'total_tokens': 203, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'cortecs/Mistral-Small-24B-Instruct-2501-FP8-Dynamic', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-45c2f6dd-427c-4733-8988-e28eabc6227f-0', usage_metadata={'input_tokens': 181, 'output_tokens': 22, 'total_tokens': 203, 'input_token_details': {}, 'output_token_details': {}})
